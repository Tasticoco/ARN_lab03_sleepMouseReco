# %% [markdown]
# # Start of the lab 03
# #### By Haeffner Edwin and Junod Arthur
#
# ## Concatenation of the two dataframes

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as pl

mice_eeg1 = pd.read_csv('/content/drive/MyDrive/EEG_mouse_data_1.csv')
mice_eeg2 = pd.read_csv('/content/drive/MyDrive/EEG_mouse_data_2.csv')

mice_eeg = pd.concat([mice_eeg1, mice_eeg2], axis=0)
mice_eeg = np.array(mice_eeg)

# %% [markdown]
# ## KFold grouping

# %%
from keras import layers
from sklearn.model_selection import KFold
from sklearn.preprocessing import StandardScaler
import tensorflow.keras as keras

scaler = StandardScaler()

#normalize data
input_data = mice_eeg[:,1:26]
input_data = input_data.astype('float32')

output_data = mice_eeg[:,0:1]

output_data[output_data == 'w'] = 2.
output_data[output_data == 'n'] = 1.
output_data[output_data == 'r'] = 0.

output_data = output_data.astype('float32')

pl.clf()

keras.utils.set_random_seed(123)
kf = KFold(n_splits=3, shuffle=True)

for i, (train_index, test_index) in enumerate(kf.split(mice_eeg)):
    print(f"Fold {i}:")
    print(f"  Train: index={train_index}")
    print(f"  Test:  index={test_index}")
# Out:
# Fold 0:
#   Train: index=[    0     2     3 ... 40860 40861 40862]
#   Test:  index=[    1     8    15 ... 40854 40856 40857]
# Fold 1:
#   Train: index=[    0     1     4 ... 40859 40860 40862]
#   Test:  index=[    2     3     5 ... 40855 40858 40861]
# Fold 2:
#   Train: index=[    1     2     3 ... 40857 40858 40861]
#   Test:  index=[    0     4     6 ... 40859 40860 40862]

# %% [markdown]
# ## Data normalization

# %%
from keras import regularizers

def create_model():
    mlp = keras.Sequential([
        layers.Input(25),
        layers.Dense(32,kernel_regularizer=regularizers.l2(0.0001), activation="tanh"),
        layers.Dense(32,kernel_regularizer=regularizers.l2(0.0001), activation="tanh"),
        layers.Dense(3)
    ])

    mlp.compile(
        optimizer=keras.optimizers.SGD(learning_rate=0.001, momentum=0.8),
        loss=keras.losses.SparseCategoricalCrossentropy(from_logits=True),
        metrics=["accuracy"]
    )

    return mlp

mlp = create_model()
mlp.summary()
# Out:
# Model: "sequential_5"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_15 (Dense)            (None, 32)                832
#
#  dense_16 (Dense)            (None, 32)                1056
#
#  dense_17 (Dense)            (None, 3)                 99
#
# =================================================================
# Total params: 1987 (7.76 KB)
# Trainable params: 1987 (7.76 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
from sklearn.preprocessing import LabelEncoder

# Encode the states into asleep (-1) and awake (1)


history_list = []
trained_mlp = []
history = []

mice_eeg = np.array(mice_eeg)

for i, (train_index, test_index) in enumerate(kf.split(input_data)):
    scaler = StandardScaler()
    # We need to create a new model everytime otherwise fit will continue previous training
    mlp = create_model()

    history = mlp.fit(
        x=scaler.fit_transform(input_data[train_index]), y=output_data[train_index],
        validation_data=(scaler.transform(input_data[test_index]), output_data[test_index]),
        epochs=10
    )

    history_list.append(history)
    trained_mlp.append(mlp)
# Out:
# Epoch 1/10
# 852/852 [==============================] - 2s 2ms/step - loss: 0.5404 - accuracy: 0.8051 - val_loss: 0.4148 - val_accuracy: 0.8607
# Epoch 2/10
# 852/852 [==============================] - 2s 2ms/step - loss: 0.3963 - accuracy: 0.8638 - val_loss: 0.3864 - val_accuracy: 0.8690
# Epoch 3/10
# 852/852 [==============================] - 2s 2ms/step - loss: 0.3794 - accuracy: 0.8700 - val_loss: 0.3770 - val_accuracy: 0.8713
# Epoch 4/10
# 852/852 [==============================] - 2s 2ms/step - loss: 0.3721 - accuracy: 0.8713 - val_loss: 0.3720 - val_accuracy: 0.8713
# Epoch 5/10
# 852/852 [==============================] - 2s 2ms/step - loss: 0.3679 - accuracy: 0.8719 - val_loss: 0.3690 - val_accuracy: 0.8710
# Epoch 6/10
# 852/852 [==============================] - 2s 2ms/step - loss: 0.3650 - accuracy: 0.8722 - val_loss: 0.3668 - val_accuracy: 0.8706
# Epoch 7/10
# 852/852 [==============================] - 2s 2ms/step - loss: 0.3628 - accuracy: 0.8728 - val_loss: 0.3651 - val_accuracy: 0.8709
# Epoch 8/10
# 852/852 [==============================] - 2s 2ms/step - loss: 0.3609 - accuracy: 0.8729 - val_loss: 0.3640 - val_accuracy: 0.8709
# Epoch 9/10
# 852/852 [==============================] - 2s 2ms/step - loss: 0.3595 - accuracy: 0.8732 - val_loss: 0.3627 - val_accuracy: 0.8712
# Epoch 10/10
# 852/852 [==============================] - 2s 2ms/step - loss: 0.3581 - accuracy: 0.8737 - val_loss: 0.3618 - val_accuracy: 0.8709
# Epoch 1/10
# 852/852 [==============================] - 2s 2ms/step - loss: 0.5003 - accuracy: 0.8344 - val_loss: 0.4191 - val_accuracy: 0.8556
# Epoch 2/10
# 852/852 [==============================] - 2s 2ms/step - loss: 0.4044 - accuracy: 0.8619 - val_loss: 0.3919 - val_accuracy: 0.8643
# Epoch 3/10
# 852/852 [==============================] - 2s 2ms/step - loss: 0.3864 - accuracy: 0.8681 - val_loss: 0.3788 - val_accuracy: 0.8683
# Epoch 4/10
# 852/852 [==============================] - 2s 2ms/step - loss: 0.3770 - accuracy: 0.8703 - val_loss: 0.3715 - val_accuracy: 0.8702
# Epoch 5/10
# 852/852 [==============================] - 2s 2ms/step - loss: 0.3713 - accuracy: 0.8721 - val_loss: 0.3671 - val_accuracy: 0.8710
# Epoch 6/10
# 852/852 [==============================] - 2s 2ms/step - loss: 0.3674 - accuracy: 0.8719 - val_loss: 0.3638 - val_accuracy: 0.8711
# Epoch 7/10
# 852/852 [==============================] - 2s 2ms/step - loss: 0.3646 - accuracy: 0.8724 - val_loss: 0.3615 - val_accuracy: 0.8721
# Epoch 8/10
# 852/852 [==============================] - 2s 2ms/step - loss: 0.3624 - accuracy: 0.8725 - val_loss: 0.3599 - val_accuracy: 0.8726
# Epoch 9/10
# 852/852 [==============================] - 2s 2ms/step - loss: 0.3607 - accuracy: 0.8732 - val_loss: 0.3580 - val_accuracy: 0.8738
# Epoch 10/10
# 852/852 [==============================] - 2s 2ms/step - loss: 0.3592 - accuracy: 0.8727 - val_loss: 0.3566 - val_accuracy: 0.8738
# Epoch 1/10
# 852/852 [==============================] - 2s 2ms/step - loss: 0.5078 - accuracy: 0.8209 - val_loss: 0.4076 - val_accuracy: 0.8622
# Epoch 2/10
# 852/852 [==============================] - 2s 2ms/step - loss: 0.3914 - accuracy: 0.8663 - val_loss: 0.3851 - val_accuracy: 0.8670
# Epoch 3/10
# 852/852 [==============================] - 2s 2ms/step - loss: 0.3778 - accuracy: 0.8694 - val_loss: 0.3768 - val_accuracy: 0.8688
# Epoch 4/10
# 852/852 [==============================] - 2s 2ms/step - loss: 0.3715 - accuracy: 0.8702 - val_loss: 0.3724 - val_accuracy: 0.8689
# Epoch 5/10
# 852/852 [==============================] - 2s 2ms/step - loss: 0.3677 - accuracy: 0.8705 - val_loss: 0.3696 - val_accuracy: 0.8698
# Epoch 6/10
# 852/852 [==============================] - 2s 2ms/step - loss: 0.3650 - accuracy: 0.8709 - val_loss: 0.3675 - val_accuracy: 0.8714
# Epoch 7/10
# 852/852 [==============================] - 2s 2ms/step - loss: 0.3629 - accuracy: 0.8713 - val_loss: 0.3660 - val_accuracy: 0.8717
# Epoch 8/10
# 852/852 [==============================] - 2s 2ms/step - loss: 0.3613 - accuracy: 0.8715 - val_loss: 0.3646 - val_accuracy: 0.8715
# Epoch 9/10
# 852/852 [==============================] - 2s 2ms/step - loss: 0.3599 - accuracy: 0.8727 - val_loss: 0.3637 - val_accuracy: 0.8717
# Epoch 10/10
# 852/852 [==============================] - 2s 2ms/step - loss: 0.3587 - accuracy: 0.8732 - val_loss: 0.3626 - val_accuracy: 0.8719

# %% [markdown]
# ## Plotting the training history

# %%
train_losses = np.array([history.history['loss'] for history in history_list])
val_losses = np.array([history.history['val_loss'] for history in history_list])

# Calculate mean and standard deviation for training and validation losses
mean_train_loss = np.mean(train_losses, axis=0)
std_train_loss = np.std(train_losses, axis=0)
mean_val_loss = np.mean(val_losses, axis=0)
std_val_loss = np.std(val_losses, axis=0)

# Plot mean and standard deviation for training loss
pl.plot(mean_train_loss, label='Training Loss (Mean)')
pl.fill_between(range(len(mean_train_loss)), mean_train_loss - std_train_loss, mean_train_loss + std_train_loss, alpha=0.3, label='Training Loss (Std)')

# Plot mean and standard deviation for validation loss
pl.plot(mean_val_loss, label='Validation Loss (Mean)')
pl.fill_between(range(len(mean_val_loss)), mean_val_loss - std_val_loss, mean_val_loss + std_val_loss, alpha=0.3, label='Validation Loss (Std)')

# Add labels and legend
pl.xlabel('Epochs')
pl.ylabel('Loss')
pl.legend()

# Display the plot
pl.show()

# %%
from matplotlib import pyplot as plt
from sklearn.metrics import confusion_matrix, f1_score
import seaborn as sns


def plot_confusion_matrix(confusion_matrix, title, class_labels):
    # Plot confusion matrix
    fig, ax = plt.subplots(figsize=(8, 6))
    sns.heatmap(confusion_matrix.astype(int), annot=False, fmt='', cmap="Blues", cbar=False,
                xticklabels=class_labels, yticklabels=class_labels, ax=ax)

    # Add numerical values to the heatmap
    for i in range(confusion_matrix.shape[0]):
        for j in range(confusion_matrix.shape[1]):
            x = j + 0.5  # Shift x-coordinate to center the text
            y = i + 0.5  # Shift y-coordinate to center the text
            ax.text(x, y, str(confusion_matrix[i, j]), ha="center", va="center", color="black")

    ax.set_title(title)
    ax.set_xlabel('Predicted')
    ax.set_ylabel('True')
    plt.show()

class_labels = ["REM", "Non-REM", "Wake"]

f1_scores = []
mean_confusion_matrix = np.zeros((3, 3))

for i, (train_index, test_index) in enumerate(kf.split(input_data)):
    # Evaluate the trained model on the test fold
    predictions = trained_mlp[i].predict(scaler.transform(input_data[test_index]))
    true_labels = output_data[test_index]

    # Compute confusion matrix
    cm = confusion_matrix(true_labels, predictions.argmax(axis=1))
    mean_confusion_matrix += cm

    # Compute confusion matrix and plot
    plot_confusion_matrix(cm, f'Confusion Matrix - Fold {i + 1}', class_labels)

    # Compute F1 score
    f1 = f1_score(true_labels, predictions.argmax(axis=1), average='macro')
    f1_scores.append(f1)
    print(f"F1 Score - Fold {i + 1}: {f1}")

# Plot mean confusion matrix
plot_confusion_matrix(mean_confusion_matrix.astype(int), 'Global confusion matrix', class_labels)

# Calculate and display the mean F1 score across all folds
mean_f1_score = np.mean(f1_scores)
print(f"Mean F1 Score across all folds: {mean_f1_score}")
# Out:
# 426/426 [==============================] - 1s 1ms/step
# F1 Score - Fold 1: 0.7386139655013665
# 426/426 [==============================] - 1s 1ms/step
# F1 Score - Fold 2: 0.7513597534449451
# 426/426 [==============================] - 1s 1ms/step
# F1 Score - Fold 3: 0.7486935552528711
# Mean F1 Score across all folds: 0.746222424733061

# %% [markdown]
# Get the model with the best f-score
# for

# %%
# Find the model with the highest F1 score
best_score = -float('inf')
index = 0;
i = 0;

for score in f1_scores:

    if score > best_score:
        best_score = score
        index = i

    i += 1

best_model = f1_scores[index]
best_mlp = trained_mlp[index]

print(f"Best F1 Score: {best_score}")
# Out:
# Best F1 Score: 0.7513597534449451

# %%
test = pd.read_csv('/content/drive/MyDrive/EEG_mouse_data_test.csv')
test_smol = test.iloc[:,0:25]
test_scaled = scaler.fit_transform(test_smol)

# %%
y_pred = best_mlp.predict(test_scaled)
# Out:
# 2504/2504 [==============================] - 3s 1ms/step

# %%
# Convert logits to probabilities
import numpy as np
y_pred_probs = np.exp(y_pred) / np.sum(np.exp(y_pred), axis=1, keepdims=True)

# Get predicted classes
y_pred_classes = np.argmax(y_pred_probs, axis=1)

# Count occurrences of each class
unique_counts = np.bincount(y_pred_classes)

# Compute class proportions
total_samples = len(y_pred_classes)
class_proportions = unique_counts / total_samples

# Map numerical values to class labels
class_labels = ["REM", "Non-REM", "Wake"]

# Visualisation
import matplotlib.pyplot as plt

for i, count in enumerate(unique_counts):
    print(f"{class_labels[i]}: {count}")

plt.figure(figsize=(8, 4))
plt.bar(range(len(class_proportions)), class_proportions, tick_label=class_labels, color='green', alpha=0.6)
plt.xlabel('Class')
plt.ylabel('Proportion')
plt.title('Predicted Class Proportions')
plt.show()
# Out:
# REM: 2623
# Non-REM: 27222
# Wake: 50264
